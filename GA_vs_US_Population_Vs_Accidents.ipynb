# %%
import pandas as pd
# https://seaborn.pydata.org/tutorial/distributions.html

# %%
pd_ga_acci_popu = pd.read_json("https://usacity-accidents-population.herokuapp.com/gacities")

# %%
pd_ga_acci_popu.head(4)
# Out:
#        city state  population  accidents
# 0   atlanta    GA      420003      11469
# 1  columbus    GA      189885         41
# 2  savannah    GA      136286        356
# 3     macon    GA       91351        353

# %%
pd_ga_acci_popu.loc[:,["population","accidents"]].head(3)
# Out:
#    population  accidents
# 0      420003      11469
# 1      189885         41
# 2      136286        356

# %%
cd "D:\\GeorgiaTech\\ClassWork\\Project3"
# Out:
# D:\GeorgiaTech\ClassWork\Project3

# %%
pd_ga_acci_popu.to_csv("gacities.csv", index=False)

# %%
pd_all_acci_popu = pd.read_json("https://usacity-accidents-population.herokuapp.com/allcities")

# %%
pd_all_acci_popu.to_csv("alluscities.csv", index=False)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %%
# https://seaborn.pydata.org/generated/seaborn.scatterplot.html

# %%
plt.figure(figsize=(12,9))
cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
ax = sns.scatterplot(x="accidents", y="population", size="accidents", hue="accidents", sizes=(20, 200), palette=cmap
                     , hue_norm=(0, 7),data=pd_ga_acci_popu)

# %%
# https://www.drawingfromdata.com/setting-figure-size-using-seaborn-and-matplotlib
# plt.figure(figsize=(25,10))
# sns.boxplot(
#     data=pd_ga_acci_popu,
#     x='accidents',
#     y='population',
#     color='red')

# %%
# https://seaborn.pydata.org/examples/regression_marginals.html

# %%
# plt.figure(figsize=(25,10))
g = sns.jointplot(x="accidents", y="population", data=pd_ga_acci_popu,
                  kind="reg", truncate=False,
#                   xlim=(0, 60), ylim=(0, 12),
                  color="m", height=15)

# %%
# https://seaborn.pydata.org/tutorial/distributions.html

# %%
# https://seaborn.pydata.org/tutorial/distributions.html
plt.figure(figsize=(15,8))
sns.distplot(pd_ga_acci_popu.loc[:,"accidents"]);

# %%
plt.figure(figsize=(15,8))
sns.distplot(pd_ga_acci_popu.loc[:,"accidents"], kde=False, rug=True);

# %%
plt.figure(figsize=(15,8))
sns.distplot(pd_ga_acci_popu.loc[:,"population"]);

# %%
plt.figure(figsize=(15,8))
sns.distplot(pd_ga_acci_popu.loc[:,"population"], kde=False, rug=True);

# %%
plt.figure(figsize=(15,8))
sns.distplot(pd_ga_acci_popu.loc[:,"accidents"], hist=False, rug=True);

# %%
plt.figure(figsize=(15,8))
sns.distplot(pd_ga_acci_popu.loc[:,"population"], hist=False, rug=True);

# %%
with sns.axes_style("white"):
    sns.jointplot(x=pd_ga_acci_popu.loc[:,"population"], y=pd_ga_acci_popu.loc[:,"accidents"], kind="hex", color="k", height=12);

# %%
sns.jointplot(x="accidents", y="population", data=pd_ga_acci_popu, kind="kde", height=12);

# %%
sns.pairplot(pd_ga_acci_popu, height=4);

# %%
pd_all_acci_popu = pd.read_json("https://usacity-accidents-population.herokuapp.com/allcities")

# %%
pd_all_acci_popu.head(4)
# Out:
#           city state  population  accidents
# 0     new york    ny     8398748       1813
# 1  los angeles    ca     3990456      15779
# 2      chicago    il     2705994       4383
# 3      houston    tx     2325502      25228

# %%
plt.figure(figsize=(12,9))
cmap = sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)
ax = sns.scatterplot(x="accidents", y="population", size="accidents", hue="accidents", sizes=(20, 200), palette=cmap
                     , hue_norm=(0, 7),data=pd_all_acci_popu)

# %%
g = sns.jointplot(x="accidents", y="population", data=pd_all_acci_popu,
                  kind="reg", truncate=False,
#                   xlim=(0, 60), ylim=(0, 12),
                  color="m", height=15)

# %%
# https://seaborn.pydata.org/tutorial/distributions.html
plt.figure(figsize=(15,8))
sns.distplot(pd_all_acci_popu.loc[:,"accidents"]);

# %%
plt.figure(figsize=(15,8))
sns.distplot(pd_all_acci_popu.loc[:,"accidents"], kde=False, rug=True);

# %%
plt.figure(figsize=(15,8))
sns.distplot(pd_all_acci_popu.loc[:,"accidents"], hist=False, rug=True);

# %%
plt.figure(figsize=(15,8))
sns.distplot(pd_all_acci_popu.loc[:,"population"], hist=False, rug=True);

# %%
with sns.axes_style("white"):
    sns.jointplot(x=pd_all_acci_popu.loc[:,"population"], y=pd_all_acci_popu.loc[:,"accidents"], kind="hex", color="k", height=12);

# %%
sns.jointplot(x="accidents", y="population", data=pd_all_acci_popu, kind="kde", height=12);

# %%
sns.pairplot(pd_all_acci_popu, height=4);

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pd_all_acci_popu.head(1)
# Out:
#        city state  population  accidents
# 0  new york    ny     8398748       1813

# %%
pd_ga_acci_popu.head(1)
# Out:
#       city state  population  accidents
# 0  atlanta    GA      420003      11469

# %%
X = pd_all_acci_popu.loc[:,"population"]

# %%
y = pd_all_acci_popu.loc[:,"accidents"]

# %%
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (307,) (307,)

# %%
X = pd_all_acci_popu.loc[:,"population"].values.reshape(-1,1)

# %%
y = pd_all_acci_popu.loc[:,"accidents"].values.reshape(-1,1)

# %%
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (307, 1) (307, 1)

# %%
# Plot the data

### BEGIN SOLUTION

plt.scatter(X, y)

### END SOLUTION

# %%
# Split the data into training and testing

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
### END SOLUTION

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

### BEGIN SOLUTION
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
### END SOLUTION

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

### BEGIN SOLUTION
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
### END SOLUTION

# %%
# Create a LinearRegression model and fit it to the scaled training data

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
### END SOLUTION
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
 # Make predictions using the X_test_scaled data
# Plot y_test_scaled vs y_test_scaled
# Scatter plot y_test_scaled vs predictions

### BEGIN SOLUTION
predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()
### END SOLUTION

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2

### BEGIN SOLUTION
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.7052715060388584, R2: 0.27372199453692225

# %%
# LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

### BEGIN SOLUTION
lasso = Lasso(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = lasso.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.7121498935880864, R2: 0.26663873433531105

# %%
# Ridge model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Ridge

### BEGIN SOLUTION
ridge = Ridge(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = ridge.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = ridge.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.7052814796933512, R2: 0.27371172381730535

# %%
# ElasticNet model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import ElasticNet

### BEGIN SOLUTION
elasticnet = ElasticNet(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = elasticnet.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = elasticnet.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.7098329610283857, R2: 0.2690246766906218

# %%
pd_ga_acci_popu.head(1)
# Out:
#       city state  population  accidents
# 0  atlanta    GA      420003      11469

# %%
X = pd_ga_acci_popu.loc[:,"population"]

# %%
y = pd_ga_acci_popu.loc[:,"accidents"]

# %%
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (154,) (154,)

# %%
X = pd_ga_acci_popu.loc[:,"population"].values.reshape(-1,1)
y = pd_ga_acci_popu.loc[:,"accidents"].values.reshape(-1,1)
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (154, 1) (154, 1)

# %%
# Plot the data

### BEGIN SOLUTION

plt.scatter(X, y)

### END SOLUTION

# %%
# Split the data into training and testing

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
### END SOLUTION

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

### BEGIN SOLUTION
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
### END SOLUTION

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

### BEGIN SOLUTION
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
### END SOLUTION

# %%
# Create a LinearRegression model and fit it to the scaled training data

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
### END SOLUTION
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
 # Make predictions using the X_test_scaled data
# Plot y_test_scaled vs y_test_scaled
# Scatter plot y_test_scaled vs predictions

### BEGIN SOLUTION
predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()
### END SOLUTION

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2

### BEGIN SOLUTION
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)
### END SOLUTION

# %%
print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.03882353839304961, R2: -11.006306357351173

# %%
# LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

### BEGIN SOLUTION
lasso = Lasso(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = lasso.score(X_test_scaled, y_test_scaled)
### END SOLUTION

# %%
print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.037771299696975624, R2: -10.680898095532726

# %%
# Ridge model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Ridge

### BEGIN SOLUTION
ridge = Ridge(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = ridge.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = ridge.score(X_test_scaled, y_test_scaled)
### END SOLUTION

# %%
print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.03881580073954939, R2: -11.003913462672946

# %%
# ElasticNet model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import ElasticNet

### BEGIN SOLUTION
elasticnet = ElasticNet(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = elasticnet.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = elasticnet.score(X_test_scaled, y_test_scaled)
### END SOLUTION

# %%
print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.03786035718494246, R2: -10.708439415263062

# %%
pd_ga_acci_popu.head(1)
# Out:
#       city state  population  accidents
# 0  atlanta    GA      420003      11469

# %%
newdf = pd_ga_acci_popu.loc[pd_ga_acci_popu.loc[:,"city"] != "atlanta", :]

# %%
X = newdf.loc[:,"population"].values.reshape(-1,1)
y = newdf.loc[:,"accidents"].values.reshape(-1,1)
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (153, 1) (153, 1)

# %%
# Plot the data

### BEGIN SOLUTION

plt.scatter(X, y)

### END SOLUTION

# %%
# Split the data into training and testing

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
### END SOLUTION

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

### BEGIN SOLUTION
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
### END SOLUTION

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

### BEGIN SOLUTION
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
### END SOLUTION

# %%
# Create a LinearRegression model and fit it to the scaled training data

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
### END SOLUTION
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
 # Make predictions using the X_test_scaled data
# Plot y_test_scaled vs y_test_scaled
# Scatter plot y_test_scaled vs predictions

### BEGIN SOLUTION
predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()
### END SOLUTION

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2

### BEGIN SOLUTION
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)
### END SOLUTION

# %%
print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.16057482771704998, R2: 0.2261046923029144

# %%
mydf = pd.read_csv("gacities.csv")

# %%
mydf
# Out:
#             city state  population  accidents
# 0        atlanta    GA      420003      11469
# 1       columbus    GA      189885         41
# 2       savannah    GA      136286        356
# 3          macon    GA       91351        353
# 4        roswell    GA       88346         80
# ..           ...   ...         ...        ...
# 149       millen    GA        3120          2
# 150     soperton    GA        3115         18
# 151  chickamauga    GA        3101          3
# 152  hogansville    GA        3060         26
# 153   grantville    GA        3041         14
#
# [154 rows x 4 columns]

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_json.html
mydf.to_json(orient='records')
# Out:
# '[{"city":"atlanta","state":"GA","population":420003,"accidents":11469},{"city":"columbus","state":"GA","population":189885,"accidents":41},{"city":"savannah","state":"GA","population":136286,"accidents":356},{"city":"macon","state":"GA","population":91351,"accidents":353},{"city":"roswell","state":"GA","population":88346,"accidents":80},{"city":"albany","state":"GA","population":77434,"accidents":46},{"city":"warner robins","state":"GA","population":66588,"accidents":15},{"city":"alpharetta","state":"GA","population":57551,"accidents":292},{"city":"marietta","state":"GA","population":56579,"accidents":546},{"city":"valdosta","state":"GA","population":54518,"accidents":50},{"city":"smyrna","state":"GA","population":51271,"accidents":182},{"city":"rome","state":"GA","population":36303,"accidents":19},{"city":"gainesville","state":"GA","population":33804,"accidents":85},{"city":"east point","state":"GA","population":33712,"accidents":1},{"city":"hinesville","state":"GA","population":33
# ...

# %%
mydf = pd.read_csv("D:\\GeorgiaTech\\ClassWork\\Project3\\US_Accidents_Dec19\\US_Accidents_2018.csv")

# %%
mydf.head(1)
# Out:
#    Unnamed: 0         ID    Source    TMC  Severity           Start_Time  \
# 0     1145140  A-1145154  MapQuest  201.0         3  2018-12-31 23:54:51
#
#               End_Time  Start_Lat  Start_Lng  End_Lat  ...  Station   Stop  \
# 0  2019-01-01 01:35:42  40.740047 -73.818512      NaN  ...    False  False
#
#   Traffic_Calming  Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0           False           False        False          Night          Night
#
#   Nautical_Twilight Astronomical_Twilight          Start_Time2
# 0             Night                 Night  2018-12-31 23:54:51
#
# [1 rows x 51 columns]

# %%
mydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892615 entries, 0 to 892614
# Data columns (total 51 columns):
# Unnamed: 0               892615 non-null int64
# ID                       892615 non-null object
# Source                   892615 non-null object
# TMC                      725683 non-null float64
# Severity                 892615 non-null int64
# Start_Time               892615 non-null object
# End_Time                 892615 non-null object
# Start_Lat                892615 non-null float64
# Start_Lng                892615 non-null float64
# End_Lat                  166932 non-null float64
# End_Lng                  166932 non-null float64
# Distance(mi)             892615 non-null float64
# Description              892615 non-null object
# Number                   325008 non-null float64
# Street                   892615 non-null object
# Side                     892615 non-null object
# City                     892605 non-null object
# ...

# %%
newdf = mydf.astype({'Amenity': 'object','Bump': 'object','Crossing': 'object','Give_Way': 'object',
          'Junction': 'object','No_Exit': 'object','Railway': 'object','Roundabout': 'object',
          'Station': 'object','Stop': 'object','Traffic_Calming': 'object','Turning_Loop': 'object',
            'Traffic_Signal': 'object'}, copy=False)

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892615 entries, 0 to 892614
# Data columns (total 51 columns):
# Unnamed: 0               892615 non-null int64
# ID                       892615 non-null object
# Source                   892615 non-null object
# TMC                      725683 non-null float64
# Severity                 892615 non-null int64
# Start_Time               892615 non-null object
# End_Time                 892615 non-null object
# Start_Lat                892615 non-null float64
# Start_Lng                892615 non-null float64
# End_Lat                  166932 non-null float64
# End_Lng                  166932 non-null float64
# Distance(mi)             892615 non-null float64
# Description              892615 non-null object
# Number                   325008 non-null float64
# Street                   892615 non-null object
# Side                     892615 non-null object
# City                     892605 non-null object
# ...

# %%
newdf.head(2).to_json(orient='records')
# Out:
# '[{"Unnamed: 0":1145140,"ID":"A-1145154","Source":"MapQuest","TMC":201.0,"Severity":3,"Start_Time":"2018-12-31 23:54:51","End_Time":"2019-01-01 01:35:42","Start_Lat":40.740047,"Start_Lng":-73.818512,"End_Lat":null,"End_Lng":null,"Distance(mi)":0.0,"Description":"Right & center lane blocked due to accident on I-495 Westbound at Exit 24 Horace Harding Expy.","Number":null,"Street":"Long Island Expy W","Side":"R","City":"Flushing","County":"Queens","State":"NY","Zipcode":"11367","Country":"US","Timezone":"US\\/Eastern","Airport_Code":"KLGA","Weather_Timestamp":"2018-12-31 23:51:00","Temperature(F)":46.9,"Wind_Chill(F)":null,"Humidity(%)":93.0,"Pressure(in)":29.8,"Visibility(mi)":5.0,"Wind_Direction":"ESE","Wind_Speed(mph)":6.9,"Precipitation(in)":0.16,"Weather_Condition":"Heavy Rain","Amenity":false,"Bump":false,"Crossing":false,"Give_Way":false,"Junction":false,"No_Exit":false,"Railway":false,"Roundabout":false,"Station":false,"Stop":false,"Traffic_Calming":false,"Traffic_Signal":false
# ...

# %%
myList = []
test = ((newdf.head(1).to_json(orient='records')).replace('false','"false"').replace('true','"true"').replace('null','""'))
(myList.append(test))
print(myList)
# Out:
# ['[{"Unnamed: 0":1145140,"ID":"A-1145154","Source":"MapQuest","TMC":201.0,"Severity":3,"Start_Time":"2018-12-31 23:54:51","End_Time":"2019-01-01 01:35:42","Start_Lat":40.740047,"Start_Lng":-73.818512,"End_Lat":"","End_Lng":"","Distance(mi)":0.0,"Description":"Right & center lane blocked due to accident on I-495 Westbound at Exit 24 Horace Harding Expy.","Number":"","Street":"Long Island Expy W","Side":"R","City":"Flushing","County":"Queens","State":"NY","Zipcode":"11367","Country":"US","Timezone":"US\\/Eastern","Airport_Code":"KLGA","Weather_Timestamp":"2018-12-31 23:51:00","Temperature(F)":46.9,"Wind_Chill(F)":"","Humidity(%)":93.0,"Pressure(in)":29.8,"Visibility(mi)":5.0,"Wind_Direction":"ESE","Wind_Speed(mph)":6.9,"Precipitation(in)":0.16,"Weather_Condition":"Heavy Rain","Amenity":"false","Bump":"false","Crossing":"false","Give_Way":"false","Junction":"false","No_Exit":"false","Railway":"false","Roundabout":"false","Station":"false","Stop":"false","Traffic_Calming":"false","Traffi
# ...

# %%
import json

# %%
json.loads(test)
# Out:
# [{'Unnamed: 0': 1145140,
#   'ID': 'A-1145154',
#   'Source': 'MapQuest',
#   'TMC': 201.0,
#   'Severity': 3,
#   'Start_Time': '2018-12-31 23:54:51',
#   'End_Time': '2019-01-01 01:35:42',
#   'Start_Lat': 40.740047,
#   'Start_Lng': -73.818512,
#   'End_Lat': '',
#   'End_Lng': '',
#   'Distance(mi)': 0.0,
#   'Description': 'Right & center lane blocked due to accident on I-495 Westbound at Exit 24 Horace Harding Expy.',
#   'Number': '',
#   'Street': 'Long Island Expy W',
#   'Side': 'R',
#   'City': 'Flushing',
#   'County': 'Queens',
#   'State': 'NY',
#   'Zipcode': '11367',
#   'Country': 'US',
#   'Timezone': 'US/Eastern',
#   'Airport_Code': 'KLGA',
#   'Weather_Timestamp': '2018-12-31 23:51:00',
#   'Temperature(F)': 46.9,
#   'Wind_Chill(F)': '',
#   'Humidity(%)': 93.0,
#   'Pressure(in)': 29.8,
#   'Visibility(mi)': 5.0,
#   'Wind_Direction': 'ESE',
#   'Wind_Speed(mph)': 6.9,
#   'Precipitation(in)': 0.16,
#   'Weather_Condition': 'Heavy Rain',
# ...

# %%
from pymongo import MongoClient
import pandas as pd

# %%
connString = "mongodb+srv://mandargogate:Password123@cluster0-x4wnf.mongodb.net/test?retryWrites=true&w=majority"    
conn = MongoClient(connString, 27017)    
conn.US_Accidents
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02-x4wnf.mongodb.net:27017', 'cluster0-shard-00-00-x4wnf.mongodb.net:27017', 'cluster0-shard-00-01-x4wnf.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='Cluster0-shard-0', ssl=True), 'US_Accidents')

# %%
conn.US_Accidents.us_accidents_2018.insert(json.loads(newdf.to_json(orient='records')))
# Out:
# C:\Users\magogate\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-206-272261594196> in <module>
# ----> 1 conn.US_Accidents.us_accidents_2018.insert(json.loads(newdf.to_json(orient='records')))
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in insert(self, doc_or_docs, manipulate, check_keys, continue_on_error, **kwargs)
#    3180             write_concern = WriteConcern(**kwargs)
#    3181         return self._insert(doc_or_docs, not continue_on_error,
# -> 3182                             check_keys, manipulate, write_concern)
#    3183
#    3184     def update(self, spec, document, upsert=False, manipulate=False,
#
# ...
